# %% [markdown]
# <a href="https://colab.research.google.com/github/bpriyatha/Gramoday_Assignment/blob/main/Gramoday_intern.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# PART A: Fetching the prices

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
url='https://agmarknet.gov.in/SearchCmmMkt.aspx?Tx_Commodity=24&Tx_State=UP&Tx_District=1&Tx_Market=0&DateFrom=01-January-2020&DateTo=31-December-2020&Fr_Date=01-January-2020&To_Date=31-December-2020&Tx_Trend=0&Tx_CommodityHead=Potato&Tx_StateHead=Uttar+Pradesh&Tx_DistrictHead=Agra&Tx_MarketHead=--Select--'

# %%
data= pd.read_html(url)
data=pd.DataFrame(data[0])

data.shape()
# Out:
#     Sl no. District Name  ... Modal Price (Rs./Quintal)   Price Date
# 0      1.0          Agra  ...                     950.0  30 Dec 2020
# 1      2.0          Agra  ...                     850.0  29 Dec 2020
# 2      3.0          Agra  ...                     900.0  28 Dec 2020
# 3      4.0          Agra  ...                     850.0  27 Dec 2020
# 4      5.0          Agra  ...                     850.0  26 Dec 2020
# 5      6.0          Agra  ...                     850.0  25 Dec 2020
# 6      7.0          Agra  ...                    1000.0  23 Dec 2020
# 7      8.0          Agra  ...                     870.0  22 Dec 2020
# 8      9.0          Agra  ...                     850.0  21 Dec 2020
# 9     10.0          Agra  ...                     850.0  20 Dec 2020
# 10    11.0          Agra  ...                    1000.0  19 Dec 2020
# 11    12.0          Agra  ...                    1050.0  18 Dec 2020
# 12    13.0          Agra  ...                    1400.0  16 Dec 2020
# 13    14.0          Agra  ...                    1450.0  15 Dec 2020
# 14    15.0          Agra  ...                    1750.0  14 Dec 2020
# 15    16.0          Agra  ...                    1750.0  13 Dec 2020
# 16    17.0          Agra  ...                    1700.0  12 Dec 2020
# 17    18.0          Agra  ...                    2050.0  11 Dec 2020
# 18    19.0          Agra  ...                    2350.0  09 Dec 2020
# 19    20.0          Agra  ...                    2400.0  08 Dec 2020
# 20    21.0          Agra  ...                    2600.0  07 Dec 2020
# 21    22.0          Agra  ...                    2700.0  06 Dec 2020
# 22    23.0          Agra  ...                    2800.0  05 Dec 2020
# 23    24.0          Agra  ...                    2840.0  04 Dec 2020
# 24    25.0          Agra  ...                    2800.0  02 Dec 2020
# 25    26.0          Agra  ...                    2890.0  01 Dec 2020
# 26    27.0          Agra  ...                    2880.0  30 Nov 2020
# 27    28.0          Agra  ...                    3800.0  29 Nov 2020
# 28    29.0          Agra  ...                    2860.0  28 Nov 2020
# 29    30.0          Agra  ...                    2870.0  27 Nov 2020
# 30    31.0          Agra  ...                    2900.0  25 Nov 2020
# 31    32.0          Agra  ...                    2900.0  24 Nov 2020
# 32    33.0          Agra  ...                    2880.0  23 Nov 2020
# 33    34.0          Agra  ...                    2860.0  22 Nov 2020
# 34    35.0          Agra  ...                    2880.0  21 Nov 2020
# 35    36.0          Agra  ...                    2900.0  20 Nov 2020
# 36    37.0          Agra  ...                    2880.0  18 Nov 2020
# 37    38.0          Agra  ...                    2840.0  17 Nov 2020
# 38    39.0          Agra  ...                    2840.0  16 Nov 2020
# 39    40.0          Agra  ...                    2830.0  15 Nov 2020
# 40    41.0          Agra  ...                    2830.0  14 Nov 2020
# 41    42.0          Agra  ...                    2840.0  13 Nov 2020
# 42    43.0          Agra  ...                    2820.0  11 Nov 2020
# 43    44.0          Agra  ...                    2800.0  10 Nov 2020
# 44    45.0          Agra  ...                    2800.0  09 Nov 2020
# 45    46.0          Agra  ...                    2800.0  08 Nov 2020
# 46    47.0          Agra  ...                    2820.0  07 Nov 2020
# 47    48.0          Agra  ...                    2800.0  06 Nov 2020
# 48    49.0          Agra  ...                    2800.0  04 Nov 2020
# 49    50.0          Agra  ...                    2800.0  03 Nov 2020
# 50     NaN           NaN  ...                       NaN          NaN
#
# [51 rows x 10 columns]

# %% [markdown]
# Since this URL only gives us the access to 50 datasamples, we shall download the html file and upload it to the "\content\"

# %%
data= pd.read_html('/content/Agmarknet_Price_Report (1).xls')     #path to the uploaded file
data=pd.DataFrame(data[0])
df=data.drop(['District Name','Commodity','Variety','Grade','Sl no.'],axis=1)
data.head()
# Out:
#    Sl no. District Name  ... Modal Price (Rs./Quintal)   Price Date
# 0       1          Agra  ...                       950  30 Dec 2020
# 1       2          Agra  ...                       850  29 Dec 2020
# 2       3          Agra  ...                       900  28 Dec 2020
# 3       4          Agra  ...                       850  27 Dec 2020
# 4       5          Agra  ...                       850  26 Dec 2020
#
# [5 rows x 10 columns]

# %%
df
# Out:
#      Market Name  ...   Price Date
# 0        Achnera  ...  30 Dec 2020
# 1        Achnera  ...  29 Dec 2020
# 2        Achnera  ...  28 Dec 2020
# 3        Achnera  ...  27 Dec 2020
# 4        Achnera  ...  26 Dec 2020
# ...          ...  ...          ...
# 1822    Samsabad  ...  06 Jan 2020
# 1823    Samsabad  ...  05 Jan 2020
# 1824    Samsabad  ...  04 Jan 2020
# 1825    Samsabad  ...  02 Jan 2020
# 1826    Samsabad  ...  01 Jan 2020
#
# [1827 rows x 5 columns]

# %%
df.shape
# Out:
# (1827, 5)

# %%
from datetime import datetime
from datetime import date
t=[]
for i in range(len(df['Price Date'])):

  t.append(datetime.strptime(df['Price Date'][i], '%d %b %Y'))
  t[i]=t[i].isoformat()

df['Price Date']=t
df.set_index("Price Date", inplace = True)

# %%
df=df.groupby('Market Name')

# %% [markdown]
# Filling the Missing Data of each Market

# %%
def fill(h):
  h=h.sort_values('Price Date')
  h.index = pd.DatetimeIndex(h.index)
  h = h.reindex(idx, fill_value=None)
  h=h.fillna(method ='pad')
  h=h.fillna(method='bfill')
  return h

# %%
idx = pd.date_range('2020-01-01','2020-12-31')

Agra=df.get_group('Agra')
Achnera=df.get_group('Achnera')
Fatehabad=df.get_group('Fatehabad')
Fatehpur_Sikri=df.get_group('Fatehpur Sikri')
Jagnair=df.get_group('Jagnair')
Jarar=df.get_group('Jarar')
Khairagarh=df.get_group('Khairagarh')
Samsabad=df.get_group('Samsabad')


Agra=fill(Agra)
Achnera=fill(Achnera)
Fatehabad=fill(Fatehabad)
Fatehpur_Sikri=fill(Fatehpur_Sikri)
Jagnair=fill(Jagnair)
Jarar=fill(Jarar)
Khairagarh=fill(Khairagarh)
Samsabad=fill(Samsabad)

# %%
Agra
# Out:
#            Market Name  ...  Modal Price (Rs./Quintal)
# 2020-01-01        Agra  ...                     1400.0
# 2020-01-02        Agra  ...                     1400.0
# 2020-01-03        Agra  ...                     1380.0
# 2020-01-04        Agra  ...                     1310.0
# 2020-01-05        Agra  ...                     1310.0
# ...                ...  ...                        ...
# 2020-12-27        Agra  ...                      980.0
# 2020-12-28        Agra  ...                      950.0
# 2020-12-29        Agra  ...                      950.0
# 2020-12-30        Agra  ...                      940.0
# 2020-12-31        Agra  ...                      960.0
#
# [366 rows x 4 columns]

# %% [markdown]
# Marketwise Pattern of Prices over the year

# %%
plt.xlabel('Price Date')
plt.ylabel('Modal Price')
plt.plot(Agra['Modal Price (Rs./Quintal)'])
plt.title('Market:Agra')
plt.show()
plt.plot(Achnera['Modal Price (Rs./Quintal)'])
plt.title('Market:Achnera')

plt.show()
plt.plot(Fatehabad['Modal Price (Rs./Quintal)'])
plt.title('Market:Fatehabad')
plt.show()
plt.plot(Fatehpur_Sikri['Modal Price (Rs./Quintal)'])
plt.title('Market:Fatehpur_Sikri')
plt.show()
plt.plot(Khairagarh['Modal Price (Rs./Quintal)'])
plt.title('Market:Khairagarh')
plt.show()
plt.plot(Jagnair['Modal Price (Rs./Quintal)'])
plt.title('Market:Jagnair')
plt.show()
plt.plot(Jarar['Modal Price (Rs./Quintal)'])
plt.title('Market:Jarar')
plt.show()

# %%
plt.plot(data['Modal Price (Rs./Quintal)'][0:306])
plt.title('Achnera Market Modal Price over the year')
# Out:
# Text(0.5, 1.0, 'Achnera Market Modal Price over the year')

# %%
data.shape
# Out:
# (1827, 10)

# %%
1826/365
# Out:
# 5.002739726027397

# %% [markdown]
# Predicting prices for a given market say Agra

# %%
def split_sequence(sequence, n_steps_in, n_steps_out):
	X, y = list(), list()
	for i in range(len(sequence)):
		# find the end of this pattern
		end_ix = i + n_steps_in
		out_end_ix = end_ix + n_steps_out
		# check if we are beyond the sequence
		if out_end_ix > len(sequence):
			break
		# gather input and output parts of the pattern
		seq_x, seq_y = sequence[i:end_ix], sequence[end_ix:out_end_ix]
		X.append(seq_x)
		y.append(seq_y)
	return array(X), array(y)

# %%
#defining loss funtion
import keras.backend as K
def root_mean_squared_error(y_true, y_pred):
        return K.sqrt(K.mean(K.square(y_pred - y_true)))

# %%
from keras.models import Sequential
from keras.layers import LSTM,Reshape
from keras.layers import Dense
import numpy as np
from numpy import array,hstack

 
# define input sequence
in_seq0=np.array(Agra['Min Price (Rs./Quintal)'][0:300])
in_seq1 = np.array(Agra['Modal Price (Rs./Quintal)'][0:300])
in_seq2 = np.array(Agra['Max Price (Rs./Quintal)'][0:300])
in_seq0 = in_seq0.reshape((len(in_seq0), 1))
in_seq1 = in_seq1.reshape((len(in_seq1), 1))
in_seq2 = in_seq2.reshape((len(in_seq2), 1))

# horizontally stack columns
trainset = hstack((in_seq0, in_seq1, in_seq2))

# Number of time steps
n_in = 4
n_out=2
# convert into input/output
X, y = split_sequence(trainset, n_in,n_out)

#feature are Min.Max,Modal prices of prev dates
n_features = X.shape[2]


# define model
model = Sequential()
model.add(LSTM(100, activation='relu', return_sequences=True, input_shape=(n_in, n_features)))
model.add(LSTM(100, activation='relu'))
model.add(Reshape((n_out,-1)))
model.add(Dense(n_features))
model.summary()
model.compile(optimizer='adam', loss=root_mean_squared_error)
model.fit(X, y, epochs=400, verbose=0)
# Out:
# Model: "sequential_11"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_22 (LSTM)               (None, 4, 100)            41600
# _________________________________________________________________
# lstm_23 (LSTM)               (None, 100)               80400
# _________________________________________________________________
# reshape_9 (Reshape)          (None, 2, 50)             0
# _________________________________________________________________
# dense_10 (Dense)             (None, 2, 3)              153
# =================================================================
# Total params: 122,153
# Trainable params: 122,153
# Non-trainable params: 0
# _________________________________________________________________

# %%
X.shape
# Out:
# (296, 3, 3)

# %% [markdown]
# Predicting Test Data

# %%
in_seq0=np.array(Agra['Min Price (Rs./Quintal)'][300:366])
in_seq1 = np.array(Agra['Modal Price (Rs./Quintal)'][300:366])
in_seq2 = np.array(Agra['Max Price (Rs./Quintal)'][300:366])
in_seq0 = in_seq0.reshape((len(in_seq0), 1))
in_seq1 = in_seq1.reshape((len(in_seq1), 1))
in_seq2 = in_seq2.reshape((len(in_seq2), 1))
testset = hstack((in_seq0, in_seq1, in_seq2))
X_test, y_test = split_sequence(testset, n_in,n_out)
y_pred=model.predict(X_test,verbose=0)

# %%
testset.shape
# Out:
# (66, 3)

# %% [markdown]
# Comparing Prediction and Ground truth

# %%
plt.plot(y_pred[:,1,1])
plt.plot(y_test[:,1,1])
plt.title('Prediction of Modal Price one day ahead')
plt.ylabel('Price')
plt.xlabel('Time(in days)')
plt.legend(['Preditcted Price', 'True Price'], loc='upper right')
plt.show()

# %%
#One day ahead Predictions
plt.plot(y_pred[:,0,:])
plt.title('Predicted Price Range in Nov and Dec')
plt.ylabel('Price')
plt.xlabel('Time(in days)')
plt.legend(['Min Price','Modal Price','Max Price'], loc='upper right')
plt.show()

# %%
plt.plot(y_test[:,0,:])
plt.title('True Price Range in Nov and Dec')
plt.ylabel('Price')
plt.xlabel('Time(in days)')
plt.legend(['Min Price','Modal Price','Max Price'], loc='upper right')
plt.show()
